# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
teste = pd.read_csv('testfiles/test.csv')

# %%
treino = pd.read_csv('testfiles/train.csv')

# %%
treino.head()
# Out:
#    Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0           1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1           2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2           3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
# 3           4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016
# 4           5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016
#
#    CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                  4314902            Porto Alegre                43
# 1                  2304707                  Granja                23
# 2                  2304400               Fortaleza                23
# 3                  3304557          Rio de Janeiro                33
# 4                  1302603                  Manaus                13
#
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  ...  Q041  Q042  Q043  \
# 0               RS        24       M              0.0  ...   5.0     A     A
# ...

# %%
treino['NU

# %%
plt.figure(figsize=(18,9))
sns.heatmap(treino.corr(),cmap='seismic');

# %%
pd.set_option('display.max_rows',110)
pd.set_option('display.max_columns',110)
treino.corr()['NU_NOTA_MT']
# Out:
# Unnamed: 0                     0.006530
# NU_ANO                              NaN
# CO_MUNICIPIO_RESIDENCIA        0.108850
# CO_UF_RESIDENCIA               0.107493
# NU_IDADE                      -0.061485
# TP_ESTADO_CIVIL               -0.035393
# TP_COR_RACA                   -0.157364
# TP_NACIONALIDADE              -0.034965
# CO_MUNICIPIO_NASCIMENTO        0.113416
# CO_UF_NASCIMENTO               0.112236
# TP_ST_CONCLUSAO               -0.087869
# TP_ANO_CONCLUIU                0.029039
# TP_ESCOLA                      0.069304
# TP_ENSINO                     -0.086353
# IN_TREINEIRO                  -0.022287
# CO_ESCOLA                      0.102072
# CO_MUNICIPIO_ESC               0.102517
# CO_UF_ESC                      0.100935
# TP_DEPENDENCIA_ADM_ESC         0.373233
# TP_LOCALIZACAO_ESC            -0.052961
# TP_SIT_FUNC_ESC                0.026338
# IN_BAIXA_VISAO                 0.000685
# IN_CEGUEIRA                         NaN
# ...

# %%
features = ['NU_NOTA_COMP1',
            'NU_NOTA_COMP2',
            'NU_NOTA_COMP3',
            'NU_NOTA_COMP4',
            'NU_NOTA_COMP5',
            'NU_NOTA_REDACAO',
            'NU_NOTA_CH',
            'NU_NOTA_LC',
            'NU_NOTA_CN']

todas_var = ['NU_NOTA_MT',
            'NU_NOTA_COMP1',
            'NU_NOTA_COMP2',
            'NU_NOTA_COMP3',
            'NU_NOTA_COMP4',
            'NU_NOTA_COMP5',
            'NU_NOTA_REDACAO',
            'NU_NOTA_CH',
            'NU_NOTA_LC',
            'NU_NOTA_CN']

# %%
sns.heatmap(treino[todas_var].corr(),annot=True,cmap='coolwarm');

# %%
treino[features].isnull().sum()
# Out:
# NU_NOTA_COMP1      3597
# NU_NOTA_COMP2      3597
# NU_NOTA_COMP3      3597
# NU_NOTA_COMP4      3597
# NU_NOTA_COMP5      3597
# NU_NOTA_REDACAO    3597
# NU_NOTA_CH         3389
# NU_NOTA_LC         3597
# NU_NOTA_CN         3389
# dtype: int64

# %%
treino.isnull()
# Out:
#        Unnamed: 0  NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 0           False         False   False                    False
# 1           False         False   False                    False
# 2           False         False   False                    False
# 3           False         False   False                    False
# 4           False         False   False                    False
# ...           ...           ...     ...                      ...
# 13725       False         False   False                    False
# 13726       False         False   False                    False
# 13727       False         False   False                    False
# 13728       False         False   False                    False
# 13729       False         False   False                    False
#
#        NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  SG_UF_RESIDENCIA  NU_IDADE  \
# 0                        False             False             False     False
# ...
